# %%
# !git clone https://github.com/1611Dhruv/image-gen.git
# !pip install -r image-gen/backend/requirements.txt
# !pip install diffusers["torch"]
# Out:
# Cloning into 'image-gen'...
# remote: Enumerating objects: 662, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 662 (delta 94), reused 83 (delta 61), pack-reused 499
# Receiving objects: 100% (662/662), 791.83 KiB | 12.37 MiB/s, done.
# Resolving deltas: 100% (390/390), done.
# Collecting Flask==2.1.0 (from -r image-gen/backend/requirements.txt (line 1))
#   Downloading Flask-2.1.0-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 3.5 MB/s eta 0:00:00
# Collecting Flask-Cors==3.0.9 (from -r image-gen/backend/requirements.txt (line 2))
#   Downloading Flask_Cors-3.0.9-py2.py3-none-any.whl (14 kB)
# Collecting Flask-RESTful==0.3.8 (from -r image-gen/backend/requirements.txt (line 3))
#   Downloading Flask_RESTful-0.3.8-py2.py3-none-any.whl (25 kB)
# Collecting flax==0.5.0 (from -r image-gen/backend/requirements.txt (line 4))
#   Downloading flax-0.5.0-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r image-gen/backend/requirements.txt (line 5)) (4.65.0)
# Collecting flask_cloudflared (from -r image-gen/backend/requirements.txt (line 6))
#   Downloading flask_cloudflared-0.0.14-py3-none-any.whl (6.4 kB)
# Collecting accelerate (from -r image-gen/backend/requirements.txt (line 7))
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 25.2 MB/s eta 0:00:00
# Collecting transformers (from -r image-gen/backend/requirements.txt (line 8))
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 40.4 MB/s eta 0:00:00
# Collecting diffusers (from -r image-gen/backend/requirements.txt (line 9))
#   Downloading diffusers-0.18.1.tar.gz (895 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 895.8/895.8 kB 57.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Werkzeug>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.1.0->-r image-gen/backend/requirements.txt (line 1)) (2.3.6)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.1.0->-r image-gen/backend/requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.1.0->-r image-gen/backend/requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask==2.1.0->-r image-gen/backend/requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: Six in /usr/local/lib/python3.10/dist-packages (from Flask-Cors==3.0.9->-r image-gen/backend/requirements.txt (line 2)) (1.16.0)
# Collecting aniso8601>=0.82 (from Flask-RESTful==0.3.8->-r image-gen/backend/requirements.txt (line 3))
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from Flask-RESTful==0.3.8->-r image-gen/backend/requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.22.4)
# Requirement already satisfied: jax>=0.3 in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.4.10)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (3.7.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.1.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from flask_cloudflared->-r image-gen/backend/requirements.txt (line 6)) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r image-gen/backend/requirements.txt (line 7)) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->-r image-gen/backend/requirements.txt (line 7)) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->-r image-gen/backend/requirements.txt (line 7)) (6.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->-r image-gen/backend/requirements.txt (line 7)) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->-r image-gen/backend/requirements.txt (line 8)) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->-r image-gen/backend/requirements.txt (line 8))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r image-gen/backend/requirements.txt (line 8)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r image-gen/backend/requirements.txt (line 8))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r image-gen/backend/requirements.txt (line 8))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.0 MB/s eta 0:00:00
# Collecting importlib-metadata (from diffusers->-r image-gen/backend/requirements.txt (line 9))
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers->-r image-gen/backend/requirements.txt (line 9)) (8.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->-r image-gen/backend/requirements.txt (line 8)) (2023.6.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax>=0.3->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask==2.1.0->-r image-gen/backend/requirements.txt (line 1)) (2.1.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (16.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers->-r image-gen/backend/requirements.txt (line 9)) (3.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.10/dist-packages (from optax->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.4.10+cuda11.cudnn86)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->flask_cloudflared->-r image-gen/backend/requirements.txt (line 6)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->flask_cloudflared->-r image-gen/backend/requirements.txt (line 6)) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->flask_cloudflared->-r image-gen/backend/requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->flask_cloudflared->-r image-gen/backend/requirements.txt (line 6)) (3.4)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax->flax==0.5.0->-r image-gen/backend/requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->accelerate->-r image-gen/backend/requirements.txt (line 7)) (1.3.0)
# Building wheels for collected packages: diffusers
#   Building wheel for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.18.1-py3-none-any.whl size=1247776 sha256=22ef5f62e7bbbd03fb494d79c4b269f44121d827d3904a88b8ea72392c8c01f2
#   Stored in directory: /root/.cache/pip/wheels/24/a6/0f/76cc29c67a153b1a711662ce4181c8463815f1186336ba07ec
# Successfully built diffusers
# Installing collected packages: tokenizers, safetensors, aniso8601, importlib-metadata, huggingface-hub, Flask, transformers, Flask-RESTful, Flask-Cors, flask_cloudflared, diffusers, flax, accelerate
#   Attempting uninstall: Flask
#     Found existing installation: Flask 2.2.5
#     Uninstalling Flask-2.2.5:
#       Successfully uninstalled Flask-2.2.5
#   Attempting uninstall: flax
#     Found existing installation: flax 0.6.11
#     Uninstalling flax-0.6.11:
#       Successfully uninstalled flax-0.6.11
# Successfully installed Flask-2.1.0 Flask-Cors-3.0.9 Flask-RESTful-0.3.8 accelerate-0.20.3 aniso8601-9.0.1 diffusers-0.18.1 flask_cloudflared-0.0.14 flax-0.5.0 huggingface-hub-0.16.4 importlib-metadata-6.8.0 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2
# Requirement already satisfied: diffusers[torch] in /usr/local/lib/python3.10/dist-packages (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (3.12.2)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (0.16.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (2.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (8.4.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (2.0.1+cu118)
# Requirement already satisfied: accelerate>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from diffusers[torch]) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.11.0->diffusers[torch]) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.11.0->diffusers[torch]) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.11.0->diffusers[torch]) (6.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers[torch]) (2023.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers[torch]) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.2->diffusers[torch]) (4.6.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->diffusers[torch]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->diffusers[torch]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->diffusers[torch]) (16.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers[torch]) (3.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers[torch]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers[torch]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers[torch]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers[torch]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->diffusers[torch]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->diffusers[torch]) (1.3.0)

# %%
from threading import Thread, Event

app_port = 8000
announce_url = None
cloudflared_startup = Event()

def update_announce_url(url):
    global announce_url
    announce_url = url

def start_cloudflared(port):
  from flask_cloudflared import _run_cloudflared
  try:
    announce_url = _run_cloudflared(port, 8888)
  except:
    raise
  finally:
    update_announce_url(announce_url)
    cloudflared_startup.set()

def run_with_cloudflared(thread):
    old_run = thread.run

    def new_run(*args, **kwargs):
        new_thread = Thread(target = start_cloudflared, args=(app_port, ))
        new_thread.setDaemon(True)
        new_thread.start()
        old_run(*args, **kwargs)

    thread.run = new_run

def app():
  # !python image-gen/backend/app.py --port {app_port} --save_to_disk false --img_format jpeg --output_dir generations

if __name__ == '__main__':
    t1 = Thread(target = app)
    run_with_cloudflared(t1)
    t1.start()
    cloudflared_startup.wait()
    print(f"Your url is: {announce_url}")
    t1.join()
# Out:
# <ipython-input-2-6037d0bee174>:26: DeprecationWarning: setDaemon() is deprecated, set the daemon attribute instead
#   new_thread.setDaemon(True)
#  * Downloading cloudflared for Linux x86_64...
# Your url is: https://complex-chargers-error-o.trycloudflare.com
# 2023-07-10 09:05:08.561559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/flax/struct.py:133: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /usr/local/lib/python3.10/dist-packages/flax/struct.py:133: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /usr/local/lib/python3.10/dist-packages/flax/struct.py:133: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# --> Starting the image generation server. This might take up to two minutes.
# Downloading (…)ain/model_index.json: 100% 541/541 [00:00<00:00, 3.12MB/s]
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 812kB/s]
#
# Downloading (…)_encoder/config.json: 100% 612/612 [00:00<00:00, 3.06MB/s]
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 3.32MB/s]
#
# Downloading (…)okenizer_config.json: 100% 806/806 [00:00<00:00, 6.39MB/s]
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 2.43MB/s]
#
# Fetching 14 files:   7% 1/14 [00:00<00:02,  4.48it/s]
#
# Downloading model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# Downloading (…)e03/unet/config.json: 100% 743/743 [00:00<00:00, 3.47MB/s]
#
#
#
#
# Downloading (…)fe03/vae/config.json: 100% 547/547 [00:00<00:00, 2.50MB/s]
#
#
#
#
# Downloading model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 9.70MB/s]
#
#
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:08, 57.3MB/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 2.60MB/s]
#
# Downloading (…)ch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
#
#
#
# Downloading model.safetensors:   2% 10.5M/492M [00:00<00:07, 60.4MB/s]
#
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:04, 101MB/s]
# Downloading (…)ch_model.safetensors:   3% 10.5M/335M [00:00<00:05, 59.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   0% 10.5M/3.44G [00:00<00:57, 59.1MB/s]
#
# Downloading model.safetensors:  11% 52.4M/492M [00:00<00:04, 107MB/s]
# Downloading (…)ch_model.safetensors:   6% 21.0M/335M [00:00<00:03, 79.3MB/s]
#
#
#
# Downloading model.safetensors:   6% 31.5M/492M [00:00<00:05, 84.9MB/s]
#
#
#
# Downloading model.safetensors:   9% 41.9M/492M [00:00<00:05, 88.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 31.5M/3.44G [00:00<00:38, 88.2MB/s]
#
# Downloading model.safetensors:  15% 73.4M/492M [00:00<00:04, 99.6MB/s]
#
#
#
# Downloading model.safetensors:  11% 52.4M/492M [00:00<00:05, 86.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   1% 41.9M/3.44G [00:00<00:40, 83.9MB/s]
# Downloading (…)ch_model.safetensors:  13% 41.9M/335M [00:00<00:03, 80.5MB/s]
#
# Downloading model.safetensors:  17% 83.9M/492M [00:00<00:04, 92.1MB/s]
#
#
#
# Downloading model.safetensors:  13% 62.9M/492M [00:00<00:05, 84.2MB/s]
# Downloading (…)ch_model.safetensors:  16% 52.4M/335M [00:00<00:03, 81.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 52.4M/3.44G [00:00<00:41, 81.1MB/s]
#
# Downloading model.safetensors:  19% 94.4M/492M [00:01<00:04, 86.8MB/s]
# Downloading (…)ch_model.safetensors:  19% 62.9M/335M [00:00<00:03, 82.6MB/s]
#
#
#
# Downloading model.safetensors:  15% 73.4M/492M [00:00<00:05, 82.0MB/s]
# Downloading (…)ch_model.safetensors:  22% 73.4M/335M [00:00<00:02, 87.5MB/s]
#
#
#
# Downloading model.safetensors:  17% 83.9M/492M [00:00<00:04, 87.5MB/s]
#
# Downloading model.safetensors:  21% 105M/492M [00:01<00:04, 85.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 73.4M/3.44G [00:00<00:39, 84.3MB/s]
#
#
#
# Downloading model.safetensors:  19% 94.4M/492M [00:01<00:04, 86.7MB/s]
# Downloading (…)ch_model.safetensors:  25% 83.9M/335M [00:01<00:02, 84.1MB/s]
#
# Downloading model.safetensors:  23% 115M/492M [00:01<00:04, 85.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   2% 83.9M/3.44G [00:01<00:39, 84.0MB/s]
#
#
#
# Downloading model.safetensors:  21% 105M/492M [00:01<00:04, 89.0MB/s]
# Downloading (…)ch_model.safetensors:  28% 94.4M/335M [00:01<00:02, 84.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 94.4M/3.44G [00:01<00:39, 83.6MB/s]
#
# Downloading model.safetensors:  26% 126M/492M [00:01<00:04, 82.5MB/s]
#
#
#
# Downloading model.safetensors:  23% 115M/492M [00:01<00:04, 89.4MB/s]
#
# Downloading model.safetensors:  28% 136M/492M [00:01<00:04, 86.0MB/s]
# Downloading (…)ch_model.safetensors:  31% 105M/335M [00:01<00:02, 82.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 105M/3.44G [00:01<00:39, 84.3MB/s]
#
# Downloading model.safetensors:  30% 147M/492M [00:01<00:04, 82.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   3% 115M/3.44G [00:01<00:40, 82.5MB/s]
#
#
#
# Downloading model.safetensors:  28% 136M/492M [00:01<00:03, 97.7MB/s]
# Downloading (…)ch_model.safetensors:  38% 126M/335M [00:01<00:02, 88.5MB/s]
#
#
#
# Downloading model.safetensors:  30% 147M/492M [00:01<00:03, 91.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 126M/3.44G [00:01<00:47, 70.3MB/s]
#
# Downloading model.safetensors:  34% 168M/492M [00:01<00:03, 84.6MB/s]
# Downloading (…)ch_model.safetensors:  41% 136M/335M [00:01<00:02, 81.3MB/s]
#
#
#
# Downloading model.safetensors:  32% 157M/492M [00:01<00:03, 85.5MB/s]
#
# Downloading model.safetensors:  36% 178M/492M [00:02<00:03, 86.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 136M/3.44G [00:01<00:46, 70.3MB/s]
#
#
#
# Downloading model.safetensors:  34% 168M/492M [00:01<00:03, 81.7MB/s]
# Downloading (…)ch_model.safetensors:  44% 147M/335M [00:01<00:02, 68.8MB/s]
#
# Downloading model.safetensors:  38% 189M/492M [00:02<00:03, 80.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:   4% 147M/3.44G [00:01<00:48, 67.4MB/s]
#
#
#
# Downloading model.safetensors:  36% 178M/492M [00:02<00:03, 84.9MB/s]
# Downloading (…)ch_model.safetensors:  47% 157M/335M [00:02<00:02, 66.1MB/s]
#
# Downloading model.safetensors:  40% 199M/492M [00:02<00:04, 72.5MB/s]
#
#
#
# Downloading model.safetensors:  38% 189M/492M [00:02<00:04, 74.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 157M/3.44G [00:02<00:55, 58.6MB/s]
# Downloading (…)ch_model.safetensors:  50% 168M/335M [00:02<00:02, 60.5MB/s]
#
#
#
# Downloading model.safetensors:  40% 199M/492M [00:02<00:03, 74.0MB/s]
#
# Downloading model.safetensors:  43% 210M/492M [00:02<00:04, 63.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 168M/3.44G [00:02<00:55, 58.6MB/s]
# Downloading (…)ch_model.safetensors:  53% 178M/335M [00:02<00:02, 56.5MB/s]
#
# Downloading model.safetensors:  45% 220M/492M [00:02<00:04, 60.0MB/s]
#
#
#
# Downloading model.safetensors:  43% 210M/492M [00:02<00:04, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 178M/3.44G [00:02<01:01, 53.1MB/s]
# Downloading (…)ch_model.safetensors:  56% 189M/335M [00:02<00:02, 62.4MB/s]
#
# Downloading model.safetensors:  47% 231M/492M [00:02<00:03, 66.2MB/s]
# Downloading (…)ch_model.safetensors:  60% 199M/335M [00:02<00:02, 58.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   5% 189M/3.44G [00:02<01:02, 52.0MB/s]
#
#
#
# Downloading model.safetensors:  45% 220M/492M [00:02<00:05, 50.1MB/s]
#
# Downloading model.safetensors:  49% 241M/492M [00:03<00:04, 59.8MB/s]
# Downloading (…)ch_model.safetensors:  63% 210M/335M [00:02<00:02, 60.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 199M/3.44G [00:02<00:58, 55.6MB/s]
#
# Downloading model.safetensors:  51% 252M/492M [00:03<00:03, 60.5MB/s]
#
#
#
# Downloading model.safetensors:  47% 231M/492M [00:03<00:05, 52.0MB/s]
# Downloading (…)ch_model.safetensors:  66% 220M/335M [00:03<00:04, 25.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 210M/3.44G [00:04<03:07, 17.2MB/s]
#
# Downloading model.safetensors:  53% 262M/492M [00:07<00:27, 8.40MB/s]
#
#
#
# Downloading model.safetensors:  49% 241M/492M [00:06<00:30, 8.24MB/s]
# Downloading (…)ch_model.safetensors:  69% 231M/335M [00:06<00:11, 9.10MB/s]
#
#
# Downloading (…)ch_model.safetensors:   6% 220M/3.44G [00:06<05:44, 9.35MB/s]
#
# Downloading model.safetensors:  55% 273M/492M [00:07<00:19, 11.3MB/s]
#
#
#
# Downloading model.safetensors:  51% 252M/492M [00:07<00:21, 11.1MB/s]
# Downloading (…)ch_model.safetensors:  72% 241M/335M [00:07<00:07, 12.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 231M/3.44G [00:07<04:16, 12.5MB/s]
#
# Downloading model.safetensors:  58% 283M/492M [00:07<00:13, 15.2MB/s]
#
#
#
# Downloading model.safetensors:  53% 262M/492M [00:07<00:15, 14.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 241M/3.44G [00:07<03:13, 16.5MB/s]
# Downloading (…)ch_model.safetensors:  75% 252M/335M [00:07<00:05, 15.6MB/s]
#
# Downloading model.safetensors:  60% 294M/492M [00:07<00:10, 19.8MB/s]
#
#
#
# Downloading model.safetensors:  55% 273M/492M [00:07<00:11, 19.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   7% 252M/3.44G [00:07<02:26, 21.7MB/s]
# Downloading (…)ch_model.safetensors:  78% 262M/335M [00:07<00:03, 20.4MB/s]
#
# Downloading model.safetensors:  62% 304M/492M [00:07<00:07, 25.2MB/s]
#
#
#
# Downloading model.safetensors:  58% 283M/492M [00:07<00:08, 24.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 262M/3.44G [00:07<02:10, 24.3MB/s]
#
# Downloading model.safetensors:  64% 315M/492M [00:07<00:06, 28.9MB/s]
# Downloading (…)ch_model.safetensors:  81% 273M/335M [00:07<00:02, 23.9MB/s]
#
#
#
# Downloading model.safetensors:  60% 294M/492M [00:07<00:06, 28.7MB/s]
# Downloading (…)ch_model.safetensors:  85% 283M/335M [00:07<00:01, 29.6MB/s]
#
# Downloading model.safetensors:  66% 325M/492M [00:08<00:04, 34.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 273M/3.44G [00:07<01:47, 29.4MB/s]
#
#
#
# Downloading model.safetensors:  62% 304M/492M [00:07<00:05, 34.2MB/s]
# Downloading (…)ch_model.safetensors:  88% 294M/335M [00:07<00:01, 35.5MB/s]
#
# Downloading model.safetensors:  68% 336M/492M [00:08<00:03, 39.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:   8% 283M/3.44G [00:07<01:31, 34.6MB/s]
#
#
#
# Downloading model.safetensors:  64% 315M/492M [00:08<00:04, 38.3MB/s]
# Downloading (…)ch_model.safetensors:  91% 304M/335M [00:08<00:00, 38.4MB/s]
#
# Downloading model.safetensors:  70% 346M/492M [00:08<00:03, 41.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 294M/3.44G [00:08<01:25, 36.8MB/s]
#
#
#
# Downloading model.safetensors:  66% 325M/492M [00:08<00:04, 40.2MB/s]
# Downloading (…)ch_model.safetensors:  94% 315M/335M [00:08<00:00, 39.4MB/s]
#
# Downloading model.safetensors:  72% 357M/492M [00:08<00:03, 41.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 304M/3.44G [00:08<01:21, 38.5MB/s]
#
#
#
# Downloading model.safetensors:  68% 336M/492M [00:08<00:03, 40.5MB/s]
# Downloading (…)ch_model.safetensors:  97% 325M/335M [00:08<00:00, 43.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 315M/3.44G [00:08<01:08, 45.5MB/s]
#
# Downloading model.safetensors:  75% 367M/492M [00:08<00:02, 47.0MB/s]
#
#
#
# Downloading model.safetensors:  70% 346M/492M [00:08<00:03, 45.6MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:08<00:00, 47.5MB/s]
#
# Downloading model.safetensors:  77% 377M/492M [00:09<00:02, 50.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:   9% 325M/3.44G [00:08<01:05, 47.9MB/s]
#
#
#
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:08<00:00, 37.7MB/s]
#
#
# Downloading model.safetensors:  79% 388M/492M [00:09<00:01, 58.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 336M/3.44G [00:08<00:56, 55.4MB/s]
#
#
#
# Downloading model.safetensors:  75% 367M/492M [00:09<00:02, 54.6MB/s]
#
# Downloading model.safetensors:  81% 398M/492M [00:09<00:01, 63.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 346M/3.44G [00:09<00:49, 62.0MB/s]
#
#
#
# Downloading model.safetensors:  77% 377M/492M [00:09<00:01, 62.6MB/s]
#
# Downloading model.safetensors:  83% 409M/492M [00:09<00:01, 70.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  10% 357M/3.44G [00:09<00:45, 67.1MB/s]
#
#
#
# Downloading model.safetensors:  79% 388M/492M [00:09<00:01, 68.4MB/s]
#
# Downloading model.safetensors:  85% 419M/492M [00:09<00:00, 73.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 367M/3.44G [00:09<00:42, 73.0MB/s]
#
#
#
# Downloading model.safetensors:  81% 398M/492M [00:09<00:01, 73.7MB/s]
#
# Downloading model.safetensors:  87% 430M/492M [00:09<00:00, 75.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 377M/3.44G [00:09<00:42, 72.0MB/s]
#
#
#
# Downloading model.safetensors:  83% 409M/492M [00:09<00:01, 74.6MB/s]
#
# Downloading model.safetensors:  89% 440M/492M [00:09<00:00, 78.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  11% 388M/3.44G [00:09<00:39, 77.8MB/s]
#
#
#
# Downloading model.safetensors:  85% 419M/492M [00:09<00:00, 78.0MB/s]
#
# Downloading model.safetensors:  92% 451M/492M [00:09<00:00, 80.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 398M/3.44G [00:09<00:37, 81.7MB/s]
#
#
#
# Downloading model.safetensors:  87% 430M/492M [00:09<00:00, 77.7MB/s]
#
# Downloading model.safetensors:  94% 461M/492M [00:10<00:00, 81.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 409M/3.44G [00:09<00:37, 80.0MB/s]
#
#
#
# Downloading model.safetensors:  89% 440M/492M [00:09<00:00, 78.3MB/s]
#
# Downloading model.safetensors:  96% 472M/492M [00:10<00:00, 80.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  12% 419M/3.44G [00:09<00:36, 82.7MB/s]
#
#
#
# Downloading model.safetensors:  92% 451M/492M [00:10<00:00, 77.3MB/s]
#
#
#
# Downloading model.safetensors:  94% 461M/492M [00:10<00:00, 82.9MB/s]
#
# Downloading model.safetensors:  98% 482M/492M [00:10<00:00, 52.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 430M/3.44G [00:10<00:57, 52.3MB/s]
#
#
#
# Downloading model.safetensors: 100% 492M/492M [00:10<00:00, 46.2MB/s]
# Downloading model.safetensors: 100% 492M/492M [00:10<00:00, 46.7MB/s]
#
#
#
# Downloading (…)ch_model.safetensors:  13% 440M/3.44G [00:10<00:52, 56.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  13% 451M/3.44G [00:10<00:46, 64.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 472M/3.44G [00:10<00:35, 82.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  14% 493M/3.44G [00:10<00:30, 96.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  15% 514M/3.44G [00:11<00:27, 106MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 535M/3.44G [00:11<00:25, 112MB/s]
#
#
# Downloading (…)ch_model.safetensors:  16% 556M/3.44G [00:11<00:25, 112MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 577M/3.44G [00:11<00:24, 115MB/s]
#
#
# Downloading (…)ch_model.safetensors:  17% 598M/3.44G [00:11<00:24, 117MB/s]
#
#
# Downloading (…)ch_model.safetensors:  18% 619M/3.44G [00:11<00:23, 122MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 640M/3.44G [00:12<00:22, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  19% 661M/3.44G [00:12<00:21, 131MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 682M/3.44G [00:12<00:20, 133MB/s]
#
#
# Downloading (…)ch_model.safetensors:  20% 703M/3.44G [00:12<00:20, 135MB/s]
#
#
# Downloading (…)ch_model.safetensors:  21% 724M/3.44G [00:12<00:20, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 744M/3.44G [00:12<00:20, 131MB/s]
#
#
# Downloading (…)ch_model.safetensors:  22% 765M/3.44G [00:12<00:20, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 786M/3.44G [00:13<00:20, 126MB/s]
#
#
# Downloading (…)ch_model.safetensors:  23% 807M/3.44G [00:13<00:20, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  24% 828M/3.44G [00:13<00:19, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 849M/3.44G [00:13<00:19, 134MB/s]
#
#
# Downloading (…)ch_model.safetensors:  25% 870M/3.44G [00:13<00:18, 136MB/s]
#
#
# Downloading (…)ch_model.safetensors:  26% 891M/3.44G [00:13<00:18, 137MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 912M/3.44G [00:14<00:18, 139MB/s]
#
#
# Downloading (…)ch_model.safetensors:  27% 933M/3.44G [00:14<00:18, 134MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 954M/3.44G [00:14<00:18, 131MB/s]
#
#
# Downloading (…)ch_model.safetensors:  28% 975M/3.44G [00:14<00:19, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  29% 996M/3.44G [00:14<00:19, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.02G/3.44G [00:14<00:19, 125MB/s]
#
#
# Downloading (…)ch_model.safetensors:  30% 1.04G/3.44G [00:15<00:43, 54.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31% 1.06G/3.44G [00:15<00:36, 65.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  31% 1.08G/3.44G [00:16<00:30, 78.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  32% 1.10G/3.44G [00:16<00:25, 90.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  33% 1.12G/3.44G [00:16<00:23, 101MB/s]
#
#
# Downloading (…)ch_model.safetensors:  33% 1.14G/3.44G [00:16<00:21, 108MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.16G/3.44G [00:16<00:19, 114MB/s]
#
#
# Downloading (…)ch_model.safetensors:  34% 1.18G/3.44G [00:16<00:18, 121MB/s]
#
#
# Downloading (…)ch_model.safetensors:  35% 1.21G/3.44G [00:17<00:17, 126MB/s]
#
#
# Downloading (…)ch_model.safetensors:  36% 1.23G/3.44G [00:17<00:17, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  36% 1.25G/3.44G [00:17<00:16, 133MB/s]
#
#
# Downloading (…)ch_model.safetensors:  37% 1.27G/3.44G [00:17<00:16, 135MB/s]
#
#
# Downloading (…)ch_model.safetensors:  38% 1.29G/3.44G [00:17<00:16, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  38% 1.31G/3.44G [00:17<00:16, 128MB/s]
#
#
# Downloading (…)ch_model.safetensors:  39% 1.33G/3.44G [00:18<00:16, 126MB/s]
#
#
# Downloading (…)ch_model.safetensors:  39% 1.35G/3.44G [00:18<00:16, 126MB/s]
#
#
# Downloading (…)ch_model.safetensors:  40% 1.37G/3.44G [00:18<00:16, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  41% 1.39G/3.44G [00:18<00:15, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  41% 1.42G/3.44G [00:18<00:15, 135MB/s]
#
#
# Downloading (…)ch_model.safetensors:  42% 1.44G/3.44G [00:18<00:14, 136MB/s]
#
#
# Downloading (…)ch_model.safetensors:  42% 1.46G/3.44G [00:18<00:14, 138MB/s]
#
#
# Downloading (…)ch_model.safetensors:  43% 1.48G/3.44G [00:19<00:14, 138MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44% 1.50G/3.44G [00:19<00:14, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  44% 1.52G/3.44G [00:19<00:14, 128MB/s]
#
#
# Downloading (…)ch_model.safetensors:  45% 1.54G/3.44G [00:19<00:14, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  45% 1.56G/3.44G [00:19<00:15, 125MB/s]
#
#
# Downloading (…)ch_model.safetensors:  46% 1.58G/3.44G [00:19<00:14, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  47% 1.60G/3.44G [00:21<00:59, 30.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  47% 1.63G/3.44G [00:22<00:45, 39.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  48% 1.65G/3.44G [00:22<00:36, 49.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  48% 1.67G/3.44G [00:22<00:29, 60.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  49% 1.69G/3.44G [00:22<00:23, 72.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50% 1.71G/3.44G [00:22<00:20, 82.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  50% 1.73G/3.44G [00:22<00:18, 89.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  51% 1.75G/3.44G [00:23<00:17, 97.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  52% 1.77G/3.44G [00:23<00:16, 102MB/s]
#
#
# Downloading (…)ch_model.safetensors:  52% 1.79G/3.44G [00:23<00:15, 108MB/s]
#
#
# Downloading (…)ch_model.safetensors:  53% 1.81G/3.44G [00:23<00:14, 114MB/s]
#
#
# Downloading (…)ch_model.safetensors:  53% 1.84G/3.44G [00:23<00:13, 118MB/s]
#
#
# Downloading (…)ch_model.safetensors:  54% 1.86G/3.44G [00:23<00:12, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  55% 1.88G/3.44G [00:24<00:12, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  55% 1.90G/3.44G [00:24<00:11, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56% 1.92G/3.44G [00:24<00:12, 121MB/s]
#
#
# Downloading (…)ch_model.safetensors:  56% 1.94G/3.44G [00:24<00:12, 119MB/s]
#
#
# Downloading (…)ch_model.safetensors:  57% 1.96G/3.44G [00:24<00:12, 120MB/s]
#
#
# Downloading (…)ch_model.safetensors:  58% 1.98G/3.44G [00:24<00:11, 122MB/s]
#
#
# Downloading (…)ch_model.safetensors:  58% 2.00G/3.44G [00:25<00:11, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  59% 2.02G/3.44G [00:26<00:43, 32.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  59% 2.04G/3.44G [00:26<00:33, 41.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  60% 2.07G/3.44G [00:27<00:25, 53.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  61% 2.09G/3.44G [00:27<00:20, 65.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  61% 2.11G/3.44G [00:27<00:17, 77.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  62% 2.13G/3.44G [00:27<00:14, 89.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 2.15G/3.44G [00:27<00:13, 96.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  63% 2.17G/3.44G [00:28<00:16, 78.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  64% 2.19G/3.44G [00:28<00:14, 88.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  64% 2.21G/3.44G [00:28<00:12, 96.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  65% 2.23G/3.44G [00:28<00:11, 104MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.25G/3.44G [00:28<00:10, 110MB/s]
#
#
# Downloading (…)ch_model.safetensors:  66% 2.28G/3.44G [00:28<00:09, 116MB/s]
#
#
# Downloading (…)ch_model.safetensors:  67% 2.30G/3.44G [00:29<00:09, 122MB/s]
#
#
# Downloading (…)ch_model.safetensors:  67% 2.32G/3.44G [00:29<00:08, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  68% 2.34G/3.44G [00:29<00:08, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69% 2.36G/3.44G [00:29<00:08, 129MB/s]
#
#
# Downloading (…)ch_model.safetensors:  69% 2.38G/3.44G [00:29<00:10, 101MB/s]
#
#
# Downloading (…)ch_model.safetensors:  70% 2.40G/3.44G [00:30<00:11, 91.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  70% 2.41G/3.44G [00:30<00:13, 78.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  70% 2.42G/3.44G [00:30<00:13, 73.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  71% 2.43G/3.44G [00:30<00:13, 72.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  71% 2.44G/3.44G [00:30<00:14, 67.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  71% 2.45G/3.44G [00:31<00:31, 31.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 2.46G/3.44G [00:31<00:26, 36.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 2.47G/3.44G [00:32<00:22, 42.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  72% 2.49G/3.44G [00:32<00:18, 51.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  73% 2.50G/3.44G [00:32<00:16, 56.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  73% 2.51G/3.44G [00:32<00:15, 60.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  73% 2.52G/3.44G [00:32<00:15, 60.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.53G/3.44G [00:32<00:18, 49.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.54G/3.44G [00:33<00:16, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.55G/3.44G [00:33<00:15, 56.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  74% 2.56G/3.44G [00:33<00:14, 60.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 2.57G/3.44G [00:33<00:14, 60.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 2.58G/3.44G [00:33<00:14, 60.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  75% 2.59G/3.44G [00:33<00:13, 62.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  76% 2.60G/3.44G [00:34<00:17, 48.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  76% 2.61G/3.44G [00:34<00:17, 47.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  76% 2.62G/3.44G [00:34<00:17, 45.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.63G/3.44G [00:34<00:15, 51.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.64G/3.44G [00:34<00:13, 56.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  77% 2.65G/3.44G [00:35<00:14, 53.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  78% 2.67G/3.44G [00:35<00:10, 72.5MB/s]
#
#
# Downloading (…)ch_model.safetensors:  78% 2.68G/3.44G [00:35<00:09, 78.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  79% 2.71G/3.44G [00:35<00:07, 94.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  79% 2.73G/3.44G [00:35<00:06, 104MB/s]
#
#
# Downloading (…)ch_model.safetensors:  80% 2.75G/3.44G [00:35<00:06, 108MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.77G/3.44G [00:36<00:06, 109MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.79G/3.44G [00:36<00:06, 98.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  81% 2.80G/3.44G [00:36<00:07, 90.9MB/s]
#
#
# Downloading (…)ch_model.safetensors:  82% 2.81G/3.44G [00:36<00:07, 88.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  82% 2.82G/3.44G [00:36<00:07, 85.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  82% 2.83G/3.44G [00:36<00:06, 87.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  83% 2.84G/3.44G [00:37<00:06, 90.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  83% 2.85G/3.44G [00:37<00:06, 92.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 2.87G/3.44G [00:37<00:05, 102MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 2.88G/3.44G [00:37<00:05, 97.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  84% 2.90G/3.44G [00:37<00:05, 90.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 2.92G/3.44G [00:37<00:05, 92.2MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 2.93G/3.44G [00:37<00:05, 89.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  85% 2.94G/3.44G [00:38<00:05, 89.8MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 2.95G/3.44G [00:38<00:06, 79.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 2.96G/3.44G [00:38<00:06, 73.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  86% 2.97G/3.44G [00:38<00:06, 72.4MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 2.98G/3.44G [00:38<00:06, 73.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 2.99G/3.44G [00:38<00:06, 72.0MB/s]
#
#
# Downloading (…)ch_model.safetensors:  87% 3.00G/3.44G [00:38<00:05, 77.7MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 3.02G/3.44G [00:39<00:04, 96.1MB/s]
#
#
# Downloading (…)ch_model.safetensors:  88% 3.04G/3.44G [00:39<00:03, 103MB/s]
#
#
# Downloading (…)ch_model.safetensors:  89% 3.06G/3.44G [00:39<00:03, 106MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 3.08G/3.44G [00:39<00:03, 110MB/s]
#
#
# Downloading (…)ch_model.safetensors:  90% 3.10G/3.44G [00:39<00:03, 104MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 3.12G/3.44G [00:40<00:02, 106MB/s]
#
#
# Downloading (…)ch_model.safetensors:  91% 3.15G/3.44G [00:40<00:02, 109MB/s]
#
#
# Downloading (…)ch_model.safetensors:  92% 3.17G/3.44G [00:40<00:02, 92.6MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 3.19G/3.44G [00:40<00:02, 97.3MB/s]
#
#
# Downloading (…)ch_model.safetensors:  93% 3.21G/3.44G [00:40<00:02, 106MB/s]
#
#
# Downloading (…)ch_model.safetensors:  94% 3.23G/3.44G [00:41<00:01, 113MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 3.25G/3.44G [00:41<00:01, 120MB/s]
#
#
# Downloading (…)ch_model.safetensors:  95% 3.27G/3.44G [00:41<00:01, 127MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 3.29G/3.44G [00:41<00:01, 123MB/s]
#
#
# Downloading (…)ch_model.safetensors:  96% 3.31G/3.44G [00:41<00:01, 122MB/s]
#
#
# Downloading (…)ch_model.safetensors:  97% 3.33G/3.44G [00:41<00:00, 125MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 3.36G/3.44G [00:42<00:00, 130MB/s]
#
#
# Downloading (…)ch_model.safetensors:  98% 3.38G/3.44G [00:42<00:00, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 3.40G/3.44G [00:42<00:00, 132MB/s]
#
#
# Downloading (…)ch_model.safetensors:  99% 3.42G/3.44G [00:42<00:00, 136MB/s]
#
#
# Downloading (…)ch_model.safetensors: 100% 3.44G/3.44G [00:42<00:00, 80.6MB/s]
# Fetching 14 files: 100% 14/14 [00:43<00:00,  3.08s/it]
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /content/image-gen/backend/app.py:64 in <module>                             │
# │                                                                              │
# │   61                                                                         │
# │   62                                                                         │
# │   63 with app.app_context():                                                 │
# │ ❱ 64 │   stable_diff_model = StableDiffusionWrapper()                        │
# │   65 │   print("--> Image generation server is up and running!")             │
# │   66                                                                         │
# │   67 if __name__ == "__main__":                                              │
# │                                                                              │
# │ /content/image-gen/backend/stable_diffusion_wrapper.py:8 in __init__         │
# │                                                                              │
# │    5 │   def __init__(self) -> None:                                         │
# │    6 │   │   model_id = "prompthero/openjourney"                             │
# │    7 │   │   pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_ │
# │ ❱  8 │   │   self.pipe = pipe.to("cuda")                                     │
# │    9 │                                                                       │
# │   10 │                                                                       │
# │   11 │   def generate_images(self, text_prompt: str, num_images: int, steps: │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/pipeline_utils.p │
# │ y:681 in to                                                                  │
# │                                                                              │
# │    678 │   │   │   │   │   f"The module '{module.__class__.__name__}' has be │
# │    679 │   │   │   │   )                                                     │
# │    680 │   │   │   else:                                                     │
# │ ❱  681 │   │   │   │   module.to(torch_device, torch_dtype)                  │
# │    682 │   │   │                                                             │
# │    683 │   │   │   if (                                                      │
# │    684 │   │   │   │   module.dtype == torch.float16                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1145 in   │
# │ to                                                                           │
# │                                                                              │
# │   1142 │   │   │   │   │   │   │   non_blocking, memory_format=convert_to_fo │
# │   1143 │   │   │   return t.to(device, dtype if t.is_floating_point() or t.i │
# │   1144 │   │                                                                 │
# │ ❱ 1145 │   │   return self._apply(convert)                                   │
# │   1146 │                                                                     │
# │   1147 │   def register_full_backward_pre_hook(                              │
# │   1148 │   │   self,                                                         │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:797 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    794 │                                                                     │
# │    795 │   def _apply(self, fn):                                             │
# │    796 │   │   for module in self.children():                                │
# │ ❱  797 │   │   │   module._apply(fn)                                         │
# │    798 │   │                                                                 │
# │    799 │   │   def compute_should_use_set_data(tensor, tensor_applied):      │
# │    800 │   │   │   if torch._has_compatible_shallow_copy_type(tensor, tensor │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:797 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    794 │                                                                     │
# │    795 │   def _apply(self, fn):                                             │
# │    796 │   │   for module in self.children():                                │
# │ ❱  797 │   │   │   module._apply(fn)                                         │
# │    798 │   │                                                                 │
# │    799 │   │   def compute_should_use_set_data(tensor, tensor_applied):      │
# │    800 │   │   │   if torch._has_compatible_shallow_copy_type(tensor, tensor │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:820 in    │
# │ _apply                                                                       │
# │                                                                              │
# │    817 │   │   │   # track autograd history of `param_applied`, so we have t │
# │    818 │   │   │   # `with torch.no_grad():`                                 │
# │    819 │   │   │   with torch.no_grad():                                     │
# │ ❱  820 │   │   │   │   param_applied = fn(param)                             │
# │    821 │   │   │   should_use_set_data = compute_should_use_set_data(param,  │
# │    822 │   │   │   if should_use_set_data:                                   │
# │    823 │   │   │   │   param.data = param_applied                            │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1143 in   │
# │ convert                                                                      │
# │                                                                              │
# │   1140 │   │   │   if convert_to_format is not None and t.dim() in (4, 5):   │
# │   1141 │   │   │   │   return t.to(device, dtype if t.is_floating_point() or │
# │   1142 │   │   │   │   │   │   │   non_blocking, memory_format=convert_to_fo │
# │ ❱ 1143 │   │   │   return t.to(device, dtype if t.is_floating_point() or t.i │
# │   1144 │   │                                                                 │
# │   1145 │   │   return self._apply(convert)                                   │
# │   1146                                                                       │
# │                                                                              │
# │ /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py:247 in        │
# │ _lazy_init                                                                   │
# │                                                                              │
# │    244 │   │   # are found or any other error occurs                         │
# │    245 │   │   if 'CUDA_MODULE_LOADING' not in os.environ:                   │
# │    246 │   │   │   os.environ['CUDA_MODULE_LOADING'] = 'LAZY'                │
# │ ❱  247 │   │   torch._C._cuda_init()                                         │
# │    248 │   │   # Some of the queued calls may reentrantly call _lazy_init(); │
# │    249 │   │   # we need to just return without initializing in that case.   │
# │    250 │   │   # However, we must not let any *other* threads in!            │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have
# an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx
